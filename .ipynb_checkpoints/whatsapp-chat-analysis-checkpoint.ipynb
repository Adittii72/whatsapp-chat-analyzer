# %%
import pandas as pd
import re

with open(
    'WhatsApp Chat with Serious discussion.txt',
    'r',
    encoding='utf-8'
) as f:
    data = f.read()

pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

messages = re.split(pattern, data)[1:]
dates = re.findall(pattern, data)

min_len = min(len(messages), len(dates))
messages = messages[:min_len]
dates = dates[:min_len]

df = pd.DataFrame({
    'message_date': dates,
    'user_message': messages
})

df['message_date'] = df['message_date'].str.replace(' - ', '')

# 🔹 7. Convert to datetime
df['message_date'] = pd.to_datetime(
    df['message_date'],
    format='%d/%m/%y, %H:%M',
    errors='coerce'
)

df.rename(columns={'message_date': 'date'}, inplace=True)

df['user_message'] = df['user_message'].str.replace('\n', ' ')
df['user_message'] = df['user_message'].str.strip()

users = []
msgs = []

for message in df['user_message']:
    entry = re.split(r'([\w\W]+?):\s', message)

    if entry[1:]:  # user exists
        users.append(entry[1])
        msgs.append(entry[2])
    else:
        users.append('group_notification')
        msgs.append(entry[0])

df['user'] = users
df['message'] = msgs

df = df[['date', 'user', 'message']]

df.head()
# Out:
#                  date                user  \
# 0 2026-01-24 23:18:00  group_notification
# 1 2026-01-24 23:18:00  group_notification
# 2 2026-01-24 23:18:00  group_notification
# 3 2026-01-24 23:18:00               Aditi
# 4 2026-01-24 23:18:00               Aditi
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. O...
# 1                             You created this group
# 2                    Bushra🌸 and Shreya 🫠 were added
# 3                                            Guyszss
# 4                                           Sunooooo

# %%
df['year'] = df['date'].dt.year
df.head()
# Out:
#                  date                user  \
# 0 2026-01-24 23:18:00  group_notification
# 1 2026-01-24 23:18:00  group_notification
# 2 2026-01-24 23:18:00  group_notification
# 3 2026-01-24 23:18:00               Aditi
# 4 2026-01-24 23:18:00               Aditi
#
#                                              message  year
# 0  Messages and calls are end-to-end encrypted. O...  2026
# 1                             You created this group  2026
# 2                    Bushra🌸 and Shreya 🫠 were added  2026
# 3                                            Guyszss  2026
# 4                                           Sunooooo  2026

# %%
df['month_name'] = df['date'].dt.month_name()
df.head()
# Out:
#                  date                user  \
# 0 2026-01-24 23:18:00  group_notification
# 1 2026-01-24 23:18:00  group_notification
# 2 2026-01-24 23:18:00  group_notification
# 3 2026-01-24 23:18:00               Aditi
# 4 2026-01-24 23:18:00               Aditi
#
#                                              message  year month_name
# 0  Messages and calls are end-to-end encrypted. O...  2026    January
# 1                             You created this group  2026    January
# 2                    Bushra🌸 and Shreya 🫠 were added  2026    January
# 3                                            Guyszss  2026    January
# 4                                           Sunooooo  2026    January

# %%
df['day'] = df['date'].dt.day
df.head()
# Out:
#                  date                user  \
# 0 2026-01-24 23:18:00  group_notification
# 1 2026-01-24 23:18:00  group_notification
# 2 2026-01-24 23:18:00  group_notification
# 3 2026-01-24 23:18:00               Aditi
# 4 2026-01-24 23:18:00               Aditi
#
#                                              message  year month_name  day
# 0  Messages and calls are end-to-end encrypted. O...  2026    January   24
# 1                             You created this group  2026    January   24
# 2                    Bushra🌸 and Shreya 🫠 were added  2026    January   24
# 3                                            Guyszss  2026    January   24
# 4                                           Sunooooo  2026    January   24

# %%
df['hour'] = df['date'].dt.hour
df.head()
# Out:
#                  date                user  \
# 0 2026-01-24 23:18:00  group_notification
# 1 2026-01-24 23:18:00  group_notification
# 2 2026-01-24 23:18:00  group_notification
# 3 2026-01-24 23:18:00               Aditi
# 4 2026-01-24 23:18:00               Aditi
#
#                                              message  year month_name  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2026    January   24
# 1                             You created this group  2026    January   24
# 2                    Bushra🌸 and Shreya 🫠 were added  2026    January   24
# 3                                            Guyszss  2026    January   24
# 4                                           Sunooooo  2026    January   24
#
#    hour
# 0    23
# 1    23
# 2    23
# 3    23
# 4    23

# %%
df['minute'] = df['date'].dt.minute
df.head()
# Out:
#                  date                user  \
# 0 2026-01-24 23:18:00  group_notification
# 1 2026-01-24 23:18:00  group_notification
# 2 2026-01-24 23:18:00  group_notification
# 3 2026-01-24 23:18:00               Aditi
# 4 2026-01-24 23:18:00               Aditi
#
#                                              message  year month_name  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2026    January   24
# 1                             You created this group  2026    January   24
# 2                    Bushra🌸 and Shreya 🫠 were added  2026    January   24
# 3                                            Guyszss  2026    January   24
# 4                                           Sunooooo  2026    January   24
#
#    hour  minute
# 0    23      18
# 1    23      18
# 2    23      18
# 3    23      18
# 4    23      18

# %%
df[df['user'] == 'Aditi'].shape
# Out:
# (309, 8)

# %%
words=[]
for message in df['message']:
    words.extend(message.split())

# %%
words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'Only',
#  'people',
#  'in',
#  'this',
#  'chat',
#  'can',
#  'read,',
#  'listen',
#  'to,',
#  'or',
#  'share',
#  'them.',
#  '*Learn',
#  'more*',
#  'You',
#  'created',
#  'this',
#  'group',
#  'Bushra🌸',
#  'and',
#  'Shreya',
#  '🫠',
#  'were',
#  'added',
#  'Guyszss',
#  'Sunooooo',
#  '?',
#  'Bda',
#  'matter',
#  'ho',
#  'gya',
#  'hai',
#  'Grp',
#  'call?',
#  'Now?',
#  'Possible?',
#  'Ok',
#  'but',
#  'voice',
#  'text?',
#  'Okay',
#  'the',
#  'rhinf',
#  'is',
#  'Thing',
#  'Ashutosh',
#  'ka',
#  'msg',
#  'aaya',
#  'ki',
#  'Sonal',
#  'se',
#  'baat',
#  'kr...',
#  'ki',
#  'inter',
#  'cluster',
#  'allow',
#  'kr',
#  'diya',
#  'hai',
#  'Toh',
#  'kya',
#  'wo',
#  'us',
#  'team',
#  'mein',
#  'join',
#  'hk',
#  'jaayegi',
#  'Aur',
#  'Ashutosh',
#  'hmari',
#  'team',
#  'mein',
#  'He',
#  'wants',
#  'to',
#  'join',
#  'our',
#  'team?',
#  'Fir',
#  'meine',
#  'Sonal',
#  'se',
#  'baat',
#  'ki',
#  'Usne',
#  'bola',
#  'ki',
#  'wo',
#  'vapis',
#  'c',
#  'class',
#  'vali',
#  'team',
#  'nhi',
#  'join',
#  'kr',
#  'rhi',
#  'Ok',
#  'Fir',
#  'usne',
#  'bola',
#  'ki',
#  'b',
#  'sec',
#  'mein',
#  'uske',
#  'dost',
#  'hai',
#  'who',
#  'are',
#  'looking',
#  'for',
#  'a',
#  'member',
#  'So',
#  'Sonal',
#  'ne',
#  'Ashutosh',
#  'ka',
#  'naam',
#  'suggest',
#  'kiya',
#  'Fir',
#  "they're",
#  'like',
#  'Ashutosh',
#  'gpa',
#  'puchho',
#  'So',
#  'ab',
#  'Sonal',
#  'yeh',
#  'bol',
#  'rhi',
#  'hai',
#  'Aditi:',
#  'Basically',
#  'ab',
#  'usko',
#  'B',
#  'sec',
#  'ki',
#  'team',
#  'join',
#  'krne',
#  'mein',
#  'dikkt',
#  'nhi',
#  'hai',
#  'Aur',
#  'hme',
#  'Ashutosh',
#  'ko',
#  'lena',
#  'hai',
#  'Oh',
#  'And',
#  'the',
#  'b',
#  'sec',
#  'shes',
#  'talking',
#  'about',
#  'is',
#  'it',
#  'our',
#  'cls',
#  'akanksha',
#  'anu',
#  'm',
#  'one',
#  'b',
#  'sec',
#  'girl',
#  'Nah',
#  'nah',
#  'Oh',
#  'Aparajita',
#  'naam',
#  'hai',
#  'Why',
#  "didn't",
#  'he',
#  'find',
#  'a',
#  'team',
#  'for',
#  'himself',
#  'earlier',
#  '😭',
#  'Sonal',
#  'ne',
#  'btaya',
#  'tha',
#  'He',
#  'did',
#  'With',
#  'chandrathanaya',
#  'Bt',
#  'then',
#  'wo',
#  'team',
#  'un',
#  'logo',
#  'ne',
#  'tod',
#  'di',
#  'Chandrathanaya',
#  'uski',
#  'mini',
#  'project',
#  'vali',
#  'mein',
#  'join',
#  'kr',
#  'liya',
#  'Oh',
#  'ok',
#  'yeah',
#  'those',
#  'topper',
#  'girls',
#  'Oh',
#  'okk',
#  'Aur',
#  'Ashutosh',
#  'ko',
#  'akela',
#  'kr',
#  'diya',
#  'Fine',
#  'then',
#  'Was',
#  'he',
#  'causing',
#  'trouble',
#  'Or',
#  'just',
#  'Delaying',
#  'works',
#  'Last',
#  'time',
#  'Nothing',
#  'as',
#  'such',
#  'Cos',
#  'during',
#  'sih',
#  'he',
#  'was',
#  'active',
#  'only',
#  'If',
#  "we're",
#  'comparing',
#  'those',
#  'two',
#  'Then',
#  'we',
#  'would',
#  'prefer',
#  'Sonal',
#  "That's",
#  'it',
#  'Ashutosh',
#  'does',
#  'his',
#  'job',
#  'perfectly...',
#  'Its',
#  'just',
#  "he's",
#  'cool',
#  'type',
#  'of',
#  'person',
#  'Hmm',
#  'He',
#  "doesn't",
#  'take',
#  'things',
#  'srsly',
#  'as',
#  'we',
#  'do',
#  'Okay',
#  'but',
#  'i',
#  'already',
#  'have',
#  'major',
#  'project',
#  'idea',
#  'Would',
#  'he',
#  'agree',
#  'for',
#  'that',
#  'First',
#  "we've",
#  'to',
#  'decide',
#  'for',
#  'thr',
#  'member',
#  'Yeah',
#  'im',
#  'okay',
#  'Then',
#  'we',
#  'shud',
#  'go',
#  'for',
#  'idea',
#  'Bro',
#  'till',
#  'wht',
#  'time',
#  "uh're",
#  'up?',
#  'Around',
#  '12',
#  'yeah',
#  'after',
#  'that',
#  'ill',
#  'ho',
#  'for',
#  'sleep',
#  'Fine',
#  'be',
#  'up',
#  'Sorry',
#  'guys',
#  'mein',
#  'jaldi',
#  'so',
#  'gyi',
#  'Aaj',
#  'travel',
#  'karna',
#  'tha',
#  'Kya',
#  'decide',
#  'hua',
#  'Tu',
#  'apna',
#  'bta',
#  'Mujhe',
#  'lakta',
#  'hai',
#  'sonal',
#  'ko',
#  'lene',
#  'chahiye',
#  'Dono',
#  'hi',
#  'responsible',
#  'hai',
#  'aise',
#  'tho',
#  'Abhi',
#  'kya',
#  'krna',
#  'hai',
#  'Bushra?',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'But',
#  'If',
#  "he's",
#  'saying',
#  'he',
#  'wants',
#  'to',
#  'do',
#  'in',
#  'our',
#  'grp',
#  'i',
#  "don't",
#  'hv',
#  'as',
#  'like',
#  'any',
#  'issue',
#  'Thik',
#  'hai',
#  'fir',
#  'Sonal',
#  'ko',
#  'hi',
#  'bolde',
#  'Ashutosh',
#  'ko',
#  'us',
#  'team',
#  'mein',
#  'add',
#  'krne',
#  'ko',
#  'Aditi:',
#  'Guys',
#  'Ashutosh',
#  'ko',
#  'Ankit',
#  'logo',
#  'ne',
#  'le',
#  'liya',
#  'hai',
#  'Aditya',
#  'ko',
#  'nikal',
#  'diya',
#  'Oh',
#  'Guys',
#  'Mein',
#  'aur',
#  'varshini',
#  'Bahar',
#  'jaa',
#  'rhe',
#  'hai',
#  'For',
#  'snacks',
#  'Wanna',
#  'join?',
#  'Bushra🌸',
#  'added',
#  'Varshini',
#  '💫🤌',
#  'Aditi:',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'Set',
#  'a',
#  'guy',
#  'beside',
#  'me',
#  'which',
#  'uh',
#  'think',
#  'will',
#  'suit',
#  'the',
#  'best.',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'Thank',
#  'u',
#  'so',
#  'much',
#  'guys♥️♥️💖',
#  '<Media',
#  'omitted>',
#  'Give',
#  'project',
#  'title',
#  'for',
#  'machine',
#  'learning',
#  'research',
#  'then',
#  'finalize',
#  'which',
#  'is',
#  'a',
#  'real',
#  'world',
#  'industry',
#  'problem,',
#  'has',
#  'novelity',
#  'is',
#  'rare',
#  '(rarity)',
#  'has',
#  'technical',
#  'depth',
#  'n',
#  'advantages.',
#  'ans',
#  'is',
#  'fir',
#  'for',
#  'Machine',
#  'learning',
#  'research',
#  '*fit',
#  'we',
#  'have',
#  'a',
#  'very',
#  'strict',
#  'ml',
#  'professor',
#  'who',
#  'denads',
#  'us',
#  'to',
#  'do',
#  'a',
#  'research',
#  'on',
#  'any',
#  'problem',
#  'statement',
#  'and',
#  'tehn',
#  'create',
#  'a',
#  'eresearch',
#  'paper',
#  'on',
#  'the',
#  'same',
#  '.',
#  'the',
#  'problem',
#  'stattement',
#  'should',
#  'be',
#  'novel,not',
#  'aopplication',
#  'based,',
#  'should',
#  'be',
#  'ml',
#  'based',
#  ',',
#  'there',
#  'should',
#  'not',
#  'be',
#  'any',
#  'existing',
#  'solutions,',
#  'also',
#  'he',
#  'solution',
#  'cannot',
#  'be',
#  'created',
#  'by',
#  'any',
#  'ai',
#  'agents',
#  'ml',
#  'agents',
#  'etc.',
#  'basically',
#  'he',
#  'wants',
#  'a',
#  'real',
#  'world',
#  'industry',
#  'problem',
#  'statement',
#  'and',
#  'should',
#  'be',
#  'able',
#  'to',
#  'solve',
#  'them',
#  '.',
#  'gice',
#  'sme',
#  'such',
#  'probllem',
#  'statemnets',
#  'https://share.google/aimode/GoIF9uCauGKmp0dsL',
#  'Ml',
#  'cca',
#  'Synopsis',
#  'Discussion',
#  'at',
#  'wht',
#  'time?',
#  'After',
#  'dinner?',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  '"Stochastic',
#  'Graph',
#  'Neural',
#  'Networks',
#  'for',
#  'Zero-Shot',
#  'Propagation',
#  'of',
#  'Geopolitical',
#  'Shocks',
#  'in',
#  'Global',
#  'Supply',
#  'Chains"',
#  'The',
#  'deterministic',
#  'frameworks',
#  'used',
#  'in',
#  'current',
#  'supply',
#  'chain',
#  'models',
#  'break',
#  'down',
#  'in',
#  'the',
#  'face',
#  'of',
#  'abrupt',
#  'geopolitical',
#  'changes',
#  'like',
#  'trade',
#  'restrictions',
#  'or',
#  'tariff',
#  'impositions.',
#  'Due',
#  'to',
#  'a',
#  'lack',
#  'of',
#  'historical',
#  'precedents,',
#  'traditional',
#  'deep',
#  'learning',
#  'is',
#  'unable',
#  'to',
#  'predict',
#  'Out-of-Distribution',
#  '(OOD)',
#  'shocks,',
#  'which',
#  'are',
#  'represented',
#  'by',
#  'these',
#  '"Black',
#  'Swan"',
#  'events.',
#  'In',
#  'order',
#  'to',
#  'measure',
#  'risk',
#  'propagation',
#  'across',
#  'intricate',
#  'trade',
#  'networks,',
#  'this',
#  'study',
#  'suggests',
#  'a',
#  'novel',
#  'Stochastic',
#  'Graph',
#  'Neural',
#  'Network',
#  '(GNN)',
#  'architecture',
#  'that',
#  'combines',
#  'Bayesian',
#  'Inference',
#  'with',
#  'Structural',
#  'Causal',
#  'Models.',
#  'The',
#  'model',
#  'facilitates',
#  'Zero-Shot',
#  'Counterfactual',
#  'Reasoning',
#  'by',
#  'projecting',
#  'unstructured',
#  'geopolitical',
#  'latent',
#  'variables',
#  'onto',
#  'structured',
#  'supply',
#  'chain',
#  'graphs.',
#  'The',
#  'application',
#  'offers',
#  'SMEs',
#  'a',
#  'high-fidelity',
#  'Resilience',
#  'Engine',
#  'that',
#  'optimizes',
#  '"Total',
#  'Landed',
#  'Cost"',
#  'in',
#  'real-time.',
#  'By',
#  'bridging',
#  'the',
#  'gap',
#  'between',
#  'quantitative',
#  'operational',
#  'optimization',
#  'and',
#  'qualitative',
#  'geopolitical',
#  'volatility,',
#  'this',
#  'method',
#  'provides',
#  'a',
#  'mathematically',
#  'sound',
#  'solution',
#  'to',
#  'global',
#  '"While',
#  'this',
#  'framework',
#  'pushes',
#  'the',
#  'boundaries',
#  'of',
#  'traditional',
#  'ML,',
#  'it',
#  'faces',
#  'the',
#  'inherent',
#  'computational',
#  'intensity',
#  'required',
#  'for',
#  'Stochastic',
#  'Message',
#  'Passing',
#  'across',
#  'global',
#  'networks.',
#  'We',
#  'recognize',
#  'a',
#  'necessary',
#  'Interpretability-Performance',
#  'trade-off,',
#  'where',
#  'we',
#  'intentionally',
#  'prioritize',
#  'Neuro-Symbolic',
#  'logic',
#  'and',
#  'physical',
#  'consistency',
#  'over',
#  'the',
#  'raw',
#  'speed',
#  'of',
#  'a',
#  "'black-box'",
#  'approach.',
#  'Furthermore,',
#  'while',
#  'our',
#  'VAE',
#  'effectively',
#  'distills',
#  'geopolitical',
#  'noise,',
#  'the',
#  'model',
#  'remains',
#  'sensitive',
#  'to',
#  'the',
#  'Signal-to-Noise',
#  'ratio',
#  'of',
#  'unstructured',
#  'data.',
#  'Ultimately,',
#  'we',
#  'do',
#  'not',
#  'claim',
#  'to',
#  'predict',
#  "'Unknown",
#  "Unknowns'",
#  'with',
#  'absolute',
#  'certainty;',
#  'rather,',
#  'we',
#  'provide',
#  'a',
#  'mathematically',
#  'rigorous',
#  'tool',
#  'for',
#  'Uncertainty',
#  'Quantification',
#  'in',
#  'an',
#  'increasingly',
#  'non-stationary',
#  'world.',
#  'Current',
#  'SOTA',
#  'models',
#  '(LSTMs/Transformers)',
#  'rely',
#  'on',
#  'stationary',
#  'data',
#  'assumptions,',
#  'failing',
#  'during',
#  '"Black',
#  'Swan"',
#  'geopolitical',
#  'shifts',
#  'where',
#  'data',
#  'distributions',
#  'change',
#  'instantly.',
#  'Unlike',
#  'existing',
#  'Deterministic',
#  'ERP',
#  'systems',
#  'that',
#  'use',
#  'reactive',
#  '"If-Then"',
#  'logic,',
#  'this',
#  'research',
#  'implements',
#  'Stochastic',
#  'Graph',
#  'Neural',
#  'Networks',
#  '(SGNN)',
#  'to',
#  'model',
#  'volatility',
#  'as',
#  'a',
#  'dynamic',
#  'variable.',
#  'While',
#  'standard',
#  'academic',
#  'GNNs',
#  'focus',
#  'on',
#  'pattern',
#  'correlation,',
#  'my',
#  'approach',
#  'integrates',
#  'Structural',
#  'Causal',
#  'Models',
#  '(SCM)',
#  'to',
#  'enable',
#  'Zero-Shot',
#  'Counterfactual',
#  'Reasoning—predicting',
#  'the',
#  'impact',
#  'of',
#  'unseen',
#  'tariffs',
#  'without',
#  'historical',
#  'precedents.',
#  ...]

# %%
len(words)
# Out:
# 3655
